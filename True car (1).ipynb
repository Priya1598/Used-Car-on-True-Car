# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
true_car=pd.read_csv(r'C:\Users\priya\OneDrive\Desktop\Projects\Technocolab\True car prediction\true_car_listings.csv')
true_car
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
tc=pd.read_csv(r'C:\Users\priya\OneDrive\Desktop\Projects\Technocolab\True car prediction\tc20171021.csv',on_bad_lines='skip')
tc
# Out:
#               Id  Price  Year  Mileage            City State  \
# 0              1  16472  2015    18681  Jefferson City    MO
# 1              2  15749  2015    27592        Highland    IN
# 2              3  16998  2015    13650           Boone    NC
# 3              4  15777  2015    25195     New Orleans    LA
# 4              5  16784  2015    22800       Las Vegas    NV
# ...          ...    ...   ...      ...             ...   ...
# 1216245  1233038  79900  2017       25    East Hanover    NJ
# 1216246  1233039  80895  2017       10    Corte Madera    CA
# 1216247  1233040  68755  2018     2500       Englewood    NJ
# 1216248  1233041  72260  2017     3201       Englewood    NJ
# 1216249  1233042  60240  2017     8342     San Leandro    CA
#
#                        Vin   Make              Model
# 0        KL4CJBSBXFB267643  Buick  EncoreConvenience
# 1        KL4CJASB5FB245057  Buick          EncoreFWD
# 2        KL4CJCSB0FB264921  Buick      EncoreLeather
# ...

# %%
true_car.columns
# Out:
# Index(['Price', 'Year', 'Mileage', 'City', 'State', 'Vin', 'Make', 'Model'], dtype='object')

# %%
tc.columns
# Out:
# Index(['Id', 'Price', 'Year', 'Mileage', 'City', 'State', 'Vin', 'Make',
#        'Model'],
#       dtype='object')

# %%
true_car.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
tc.isnull().sum()
# Out:
# Id         0
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
true_car.drop_duplicates()
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
tc.drop_duplicates()
# Out:
#               Id  Price  Year  Mileage            City State  \
# 0              1  16472  2015    18681  Jefferson City    MO
# 1              2  15749  2015    27592        Highland    IN
# 2              3  16998  2015    13650           Boone    NC
# 3              4  15777  2015    25195     New Orleans    LA
# 4              5  16784  2015    22800       Las Vegas    NV
# ...          ...    ...   ...      ...             ...   ...
# 1216245  1233038  79900  2017       25    East Hanover    NJ
# 1216246  1233039  80895  2017       10    Corte Madera    CA
# 1216247  1233040  68755  2018     2500       Englewood    NJ
# 1216248  1233041  72260  2017     3201       Englewood    NJ
# 1216249  1233042  60240  2017     8342     San Leandro    CA
#
#                        Vin   Make              Model
# 0        KL4CJBSBXFB267643  Buick  EncoreConvenience
# 1        KL4CJASB5FB245057  Buick          EncoreFWD
# 2        KL4CJCSB0FB264921  Buick      EncoreLeather
# ...

# %%
print(f'true_car (rows,columns):{true_car.shape}\n\ntc(rows,columns):{tc.shape}')
# Out:
# true_car (rows,columns):(852122, 8)
#
# tc(rows,columns):(1216250, 9)

# %%
true_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852122 entries, 0 to 852121
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Price    852122 non-null  int64
#  1   Year     852122 non-null  int64
#  2   Mileage  852122 non-null  int64
#  3   City     852122 non-null  object
#  4   State    852122 non-null  object
#  5   Vin      852122 non-null  object
#  6   Make     852122 non-null  object
#  7   Model    852122 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 52.0+ MB

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216250 entries, 0 to 1216249
# Data columns (total 9 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   Id       1216250 non-null  int64
#  1   Price    1216250 non-null  int64
#  2   Year     1216250 non-null  int64
#  3   Mileage  1216250 non-null  int64
#  4   City     1216250 non-null  object
#  5   State    1216250 non-null  object
#  6   Vin      1216250 non-null  object
#  7   Make     1216250 non-null  object
#  8   Model    1216250 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 83.5+ MB

# %%
true_car.boxplot()
# Out:
# <AxesSubplot:>

# %%
tc.boxplot()
# Out:
# <AxesSubplot:>

# %%
true_car['Mileage'].idxmax()
# Out:
# 186465

# %%
max_index = true_car['Mileage'].idxmax()
max_index
true_car = true_car.drop(max_index)

# %%
true_car.boxplot()
# Out:
# <AxesSubplot:>

# %%
true_car['Mileage'].idxmax()
# Out:
# 186464

# %%
max_index1 = tc['Mileage'].idxmax()

# %%
max_index1
# Out:
# 991642

# %%
max_index1 = tc['Mileage'].idxmax()
tc=tc.drop(max_index1)

# %%
tc.boxplot()
# Out:
# <AxesSubplot:>

# %%
tc=tc.drop(['Id'],axis=1)
tc.head()
# Out:
#    Price  Year  Mileage            City State                Vin   Make  \
# 0  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
#
#                Model
# 0  EncoreConvenience
# 1          EncoreFWD
# 2      EncoreLeather
# 3          EncoreFWD
# 4  EncoreConvenience

# %%
true_car.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
merged=pd.merge(true_car,tc, on = 'Vin')
merged
# Out:
#         Price_x  Year_x  Mileage_x            City_x State_x  \
# 0          8995    2014      35725           El Paso      TX
# 1         10888    2013      19606  Long Island City      NY
# 2          8995    2013      48851           El Paso      TX
# 3         10999    2014      39922           Windsor      CO
# 4         14799    2016      22142            Lindon      UT
# ...         ...     ...        ...               ...     ...
# 840502    63215    2017          9       Culver City      CA
# 840503    72260    2017       3201         Englewood      NJ
# 840504    55999    2016      28941      Fort Collins      CO
# 840505    60240    2017       3005       San Leandro      CA
# 840506    76995    2017       2502          New York      NY
#
#                       Vin Make_x       Model_x  Price_y  Year_y  Mileage_y  \
# 0       19VDE2E53EE000083  Acura    ILX6-Speed     8995    2014      35725
# 1       19VDE1F52DE012636  Acura    ILX5-Speed    10888    2013      19606
# ...

# %%
vin_dup = merged['Vin'].duplicated().sum()
vin_dup
# Out:
# 47

# %%
vin_dup = merged['Vin'].drop_duplicates()
vin_dup
# Out:
# 0         19VDE2E53EE000083
# 1         19VDE1F52DE012636
# 2         19VDE2E52DE000025
# 3         19VDE1F71EE003817
# 4         19UDE2F32GA001284
#                 ...
# 840502    YV1A22MK9H1013237
# 840503    YV4A22PL3H1186162
# 840504    YV4A22PL4G1000868
# 840505    YV4A22NLXH1006162
# 840506    YV4BC0ZX1H1109845
# Name: Vin, Length: 840460, dtype: object

# %%
merged['Price_x'].fillna(merged['Price_y'], inplace=True)
merged['Price'] = pd.concat([merged['Price_x'], merged['Price_y']], axis=1).iloc[:,0]
merged['Price']
# Out:
# 0          8995
# 1         10888
# 2          8995
# 3         10999
# 4         14799
#           ...
# 840502    63215
# 840503    72260
# 840504    55999
# 840505    60240
# 840506    76995
# Name: Price, Length: 840507, dtype: int64

# %%
merged.columns
# Out:
# Index(['Price_x', 'Year_x', 'Mileage_x', 'City_x', 'State_x', 'Vin', 'Make_x',
#        'Model_x', 'Price_y', 'Year_y', 'Mileage_y', 'City_y', 'State_y',
#        'Make_y', 'Model_y', 'Price'],
#       dtype='object')

# %%
merged = merged.drop(['Price_x'], axis=1)
merged = merged.drop(['Price_y'], axis=1)

# %%
merged['Year_x'].fillna(merged['Year_y'], inplace=True)
merged['Year'] = pd.concat([merged['Year_x'], merged['Year_y']], axis=1).iloc[:,0]
merged = merged.drop(['Year_x'], axis=1)
merged = merged.drop(['Year_y'], axis=1)

# %%
merged['Mileage_x'].fillna(merged['Mileage_y'], inplace=True)
merged['Mileage'] = pd.concat([merged['Mileage_x'], merged['Mileage_y']], axis=1).iloc[:,0]
merged = merged.drop(['Mileage_x'], axis=1)
merged = merged.drop(['Mileage_y'], axis=1)

# %%
merged['City_x'].fillna(merged['City_y'], inplace=True)
merged['City'] = pd.concat([merged['City_x'], merged['City_y']], axis=1).iloc[:,0]
merged = merged.drop(['City_x'], axis=1)
merged = merged.drop(['City_y'], axis=1)

# %%
merged['State_x'].fillna(merged['State_y'], inplace=True)
merged['State'] = pd.concat([merged['State_x'], merged['State_y']], axis=1).iloc[:,0]
merged = merged.drop(['State_x'], axis=1)
merged = merged.drop(['State_y'], axis=1)

# %%
merged['Make_x'].fillna(merged['Make_y'], inplace=True)
merged['Make'] = pd.concat([merged['Make_x'], merged['Make_y']], axis=1).iloc[:,0]
merged = merged.drop(['Make_x'], axis=1) 
merged = merged.drop(['Make_y'], axis=1)

# %%
merged['Model_x'].fillna(merged['Model_y'], inplace=True)
merged['Model'] = pd.concat([merged['Model_x'], merged['Model_y']], axis=1).iloc[:,0]
merged = merged.drop(['Model_x'], axis=1)
merged = merged.drop(['Model_y'], axis=1)

# %%
merged = merged.drop(['Vin'],axis=1)
merged
# Out:
#         Price  Year  Mileage              City State   Make         Model
# 0        8995  2014    35725           El Paso    TX  Acura    ILX6-Speed
# 1       10888  2013    19606  Long Island City    NY  Acura    ILX5-Speed
# 2        8995  2013    48851           El Paso    TX  Acura    ILX6-Speed
# 3       10999  2014    39922           Windsor    CO  Acura    ILX5-Speed
# 4       14799  2016    22142            Lindon    UT  Acura  ILXAutomatic
# ...       ...   ...      ...               ...   ...    ...           ...
# 840502  63215  2017        9       Culver City    CA  Volvo         S90T6
# 840503  72260  2017     3201         Englewood    NJ  Volvo        XC90T6
# 840504  55999  2016    28941      Fort Collins    CO  Volvo       XC90AWD
# 840505  60240  2017     3005       San Leandro    CA  Volvo           V90
# 840506  76995  2017     2502          New York    NY  Volvo        XC90T8
#
# [840507 rows x 7 columns]
